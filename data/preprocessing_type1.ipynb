# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import itertools
import pickle
import random
import gzip
import json
import zstd
import polars as pl

# %% [markdown]
# # No. of Comments Posted Under a Single Video by Each Author
#
# It creates dataset in "data_type1" which contains '***suspicious***' users that posted more than 8 comments (mean+2x*std*) and '***normal***' users that posted less than 5 comments (mean+1x*std*) under a single video

# %% [markdown]
# **NOTE:**
# - Most of the users in the provided comments dataset have only a single comments. So, we had to filter out active users.
# - We considered normal users with at least a total of 100 comments in lifetime to have sufficient data to distinguish between regular active users and bots.
# - We choose 100 as the threshold since mean of total comments per user is 19 with S.D of 140. So, to consider active normal users we set a threshold of comments count going above around half a S.D over mean (~100).
# - This gives us a good conservative threshold to proceed easily with comparative data analysis of bots vs normal active users since comments data is huge containing mostly users with a single comment in lifetime.

# %%
# Load YouTube Videos Metadata
df_metadata_feather = pd.read_feather("./data/yt_metadata_helper.feather")
df_metadata_feather.rename(columns={"display_id":"video_id"}, inplace=True)

# Convert df_metadata_feather to a Polars DataFrame
df_metadata_polars = pl.from_pandas(df_metadata_feather).with_columns(
    pl.col("upload_date").dt.date().alias("upload_date")  
)

# remove Pandas df from memory since not used
del df_metadata_feather 

df_metadata_polars.head()
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬──────────┬───────────┬───────────┬───────────┐
# │ categories ┆ channel_id ┆ dislike_co ┆ video_id   ┆ duration ┆ like_coun ┆ upload_da ┆ view_coun │
# │ ---        ┆ ---        ┆ unt        ┆ ---        ┆ ---      ┆ t         ┆ te        ┆ t         │
# │ str        ┆ str        ┆ ---        ┆ str        ┆ i64      ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ f64        ┆            ┆          ┆ f64       ┆ date      ┆ f64       │
# ╞════════════╪════════════╪════════════╪════════════╪══════════╪═══════════╪═══════════╪═══════════╡
# │ Film &     ┆ UCzWrhkg9e ┆ 1.0        ┆ SBqSc91Hn9 ┆ 1159     ┆ 8.0       ┆ 2016-09-2 ┆ 1057.0    │
# │ Animation  ┆ K5I8Bm3HfV ┆            ┆ g          ┆          ┆           ┆ 8         ┆           │
# │            ┆ -unA       ┆            ┆            ┆          ┆           ┆           ┆           │
# │ Film &     ┆ UCzWrhkg9e ┆ 1.0        ┆ UuugEl86ES ┆ 2681     ┆ 23.0      ┆ 2016-09-2 ┆ 12894.0   │
# │ Animation  ┆ K5I8Bm3HfV ┆            ┆ Y          ┆          ┆           ┆ 8         ┆           │
# │            ┆ -unA       ┆            ┆            ┆          ┆           ┆           ┆           │
# │ Film &     ┆ UCzWrhkg9e ┆ 779.0      ┆ oB4c-yvnbj ┆ 1394     ┆ 1607.0    ┆ 2016-09-2 ┆ 1.800602e │
# │ Animation  ┆ K5I8Bm3HfV ┆            ┆ s          ┆          ┆           ┆ 8         ┆ 6         │
# │            ┆ -unA       ┆            ┆            ┆          ┆           ┆           ┆           │
# │ Film &     ┆ UCzWrhkg9e ┆ 24.0       ┆ ZaV-gTCMV8 ┆ 5064     ┆ 227.0     ┆ 2016-09-2 ┆ 57640.0   │
# │ Animation  ┆ K5I8Bm3HfV ┆            ┆ E          ┆          ┆           ┆ 8         ┆           │
# │            ┆ -unA       ┆            ┆            ┆          ┆           ┆           ┆           │
# │ Film &     ┆ UCzWrhkg9e ┆ 13.0       ┆ cGvL7AvMfM ┆ 3554     ┆ 105.0     ┆ 2016-09-2 ┆ 86368.0   │
# │ Animation  ┆ K5I8Bm3HfV ┆            ┆ 0          ┆          ┆           ┆ 8         ┆           │
# │            ┆ -unA       ┆            ┆            ┆          ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴────────────┴──────────┴───────────┴───────────┴───────────┘

# %%
# Create filtered authors df (active users with at least 100 total comments in lifetime)
threshold_comments = 100
num_comments_authors_orignial = pd.read_csv("./data/num_comments_authors.tsv.gz", compression="infer", sep="\t")
active_users_df = num_comments_authors_orignial[num_comments_authors_orignial["video_id"]>threshold_comments]
active_users_df_polars = pl.from_pandas(active_users_df[["author"]])

del active_users_df # remove Pandas df from memory since not used

before_size = num_comments_authors_orignial.shape[0]
after_size = active_users_df_polars.shape[0]
print(f"before:\t{before_size} users\nafter:\t{after_size} users\nchange:\t{before_size/after_size:.1f} times")
# Out:
# before:	448810483 users
# after:	15386449 users
# change:	29.2 times

# %% [markdown]
# ### Create Dataset for Normal Active Users (Sample)

# %%
# %%time
# Create dataset for sampled normal users (with comments per video < threshold AND >100 comments in lifetime)

import os
import time

i = 0
chunksize = 100_000_000
processed_rows= 0
start_time = time.time()  # Record the start time
file_path = f"normal_users.parquet"

threshold = 5 # threshold = mean + 1*(std)

file_exists = os.path.exists(file_path) 
print(f"'{file_path}' exists? {file_exists}")

'''
NOTE: total_rows in youtube_comments.tsv.gz = 8_610_000_000
'''

for df in  pd.read_csv("./data/youtube_comments.tsv.gz", compression="infer", sep="\t", chunksize=chunksize): # chunksize = # of rows
    print("\nprocessing df chunk...")
    try:
        q = (
            pl.from_pandas(df)
            .lazy()  # Convert to lazy frame
            .group_by(['author', 'video_id'])
            .agg(
                comments=pl.col('video_id').count(),  # Count of video_id for each group
                likes=pl.col('likes').sum(),         # Sum of likes for each group
                replies=pl.col('replies').sum()      # Sum of replies for each group
            )
        )
    except Exception as e:
        print(f"Error encountered: {e}")
        print("Attempting to coerce non-numeric values and retry...")
        
        # Convert specific columns to numeric, coercing errors to NaN
        df['replies'] = pd.to_numeric(df['replies'], errors='coerce', downcast="integer").dropna().astype('int64')
        df['likes'] = pd.to_numeric(df['likes'], errors='coerce', downcast="integer").dropna().astype('int64')

        # Retry loading into Polars
        q = (
            pl.from_pandas(df)
            .lazy()
            .group_by(['author', 'video_id'])
            .agg(
                comments=pl.col('video_id').count(),
                likes=pl.col('likes').sum(),
                replies=pl.col('replies').sum()
            )
        )
    
    df_polars = q.collect()

    # filter normal users with comments per day < threshold
    df_polars = q.collect().filter(pl.col('comments') < threshold)

    # filter active users (with at least 100 comments in lifetime)
    df_polars = df_polars.join(active_users_df_polars, on="author", how="inner")

    # add metadata info 
    df_polars = df_polars.join(df_metadata_polars, on="video_id", how="inner")
    
    df_polars = df_polars.with_columns([
        pl.col("replies").cast(pl.Int64)
    ])
    df_polars = df_polars.with_columns([
        pl.col("likes").cast(pl.Int64)
    ])

    # Write the first chunk or append the next chunks
    if not file_exists:
        # Write the first chunk with header
        df_polars.write_parquet(file_path, compression='zstd')
        print(f"'{file_path}' saved.")
        file_exists = True
    else:
        # For subsequent chunks, load the existing Feather file, & overwrite it with updated data (append don't work with feather)
        print(f"reading '{file_path}'...")
        df_existing = pl.read_parquet(file_path, low_memory=True)
        df_combined = pl.concat([df_existing, df_polars])
        df_combined.write_parquet(file_path, compression='zstd')
        print(f"saved '{file_path}'. ")

    # Track the number of processed rows
    processed_rows += chunksize

    # Display progress
    print(f"iteration:{i+1}, processed_rows: {processed_rows:_}")
    i += 1

    current_time = time.time()     # Record the end time
    elapsed_time = current_time - start_time
    elapsed_hours = int(elapsed_time // 3600)
    elapsed_minutes = int((elapsed_time % 3600) // 60)
    elapsed_seconds = int(elapsed_time % 60)
    print(f"Elapsed time: {elapsed_hours:02}:{elapsed_minutes:02}:{elapsed_seconds:02}\n")

# %%
# Load dataset we just created of normal active users
normal_users = pl.read_parquet("normal_users.parquet")
normal_users
# Out:
# shape: (224_746_315, 12)
# ┌──────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬─────────────┬────────────┐
# │ author   ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_date ┆ view_count │
# │ ---      ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ ---         ┆ ---        │
# │ i64      ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ date        ┆ f64        │
# ╞══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪═════════════╪════════════╡
# │ 3557393  ┆ PKk4m4ayicc ┆ 1        ┆ 4     ┆ … ┆ 2324     ┆ 9691.0     ┆ 2016-04-29  ┆ 7.782766e6 │
# │ 834253   ┆ T8zHka4w-uw ┆ 1        ┆ 0     ┆ … ┆ 10087    ┆ 1304.0     ┆ 2017-12-30  ┆ 849965.0   │
# │ 594074   ┆ hn2zYwqSINY ┆ 1        ┆ 0     ┆ … ┆ 1146     ┆ 6118.0     ┆ 2017-12-07  ┆ 4.028426e6 │
# │ 724503   ┆ UTZLSHaE4Sw ┆ 1        ┆ 0     ┆ … ┆ 1706     ┆ 2235.0     ┆ 2017-11-18  ┆ 585746.0   │
# │ 1328548  ┆ 6vY6iO0nCLo ┆ 2        ┆ 0     ┆ … ┆ 58       ┆ 537.0      ┆ 2014-03-23  ┆ 39850.0    │
# │ …        ┆ …           ┆ …        ┆ …     ┆ … ┆ …        ┆ …          ┆ …           ┆ …          │
# │ 33000590 ┆ BQGhbm7ygkY ┆ 1        ┆ 0     ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06  ┆ 6.885147e6 │
# │ 33278446 ┆ BQGhbm7ygkY ┆ 2        ┆ 0     ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06  ┆ 6.885147e6 │
# │ 33454175 ┆ BQGhbm7ygkY ┆ 1        ┆ 5     ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06  ┆ 6.885147e6 │
# │ 27226318 ┆ zVg8uqM4TXs ┆ 1        ┆ 2     ┆ … ┆ 193      ┆ 1808.0     ┆ 2017-02-13  ┆ 99581.0    │
# │ 29700245 ┆ Xies-qChApI ┆ 1        ┆ 3     ┆ … ┆ 166      ┆ 6943.0     ┆ 2017-02-13  ┆ 3.931835e6 │
# └──────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴─────────────┴────────────┘

# %%
# Unique authors per year in sampled normal users dataset
df = normal_users.clone()
result = (
    df.with_columns(pl.col("upload_date").dt.year().alias("year"))
    .group_by("year")
    .agg(pl.col("author").n_unique().alias("unique_authors"))
)

print(result)
# Out:
# shape: (15, 2)
# ┌──────┬────────────────┐
# │ year ┆ unique_authors │
# │ ---  ┆ ---            │
# │ i32  ┆ u32            │
# ╞══════╪════════════════╡
# │ 2010 ┆ 336004         │
# │ 2007 ┆ 115234         │
# │ 2013 ┆ 638841         │
# │ 2016 ┆ 812782         │
# │ 2019 ┆ 716328         │
# │ …    ┆ …              │
# │ 2015 ┆ 763894         │
# │ 2018 ┆ 788401         │
# │ 2009 ┆ 329552         │
# │ 2006 ┆ 43929          │
# │ 2012 ┆ 532896         │
# └──────┴────────────────┘

# %%
# Display normal users dataset sorted by author id
normal_users_sorted = normal_users.sort(by="author")
normal_users_sorted
# Out:
# shape: (224_746_315, 12)
# ┌──────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬─────────────┬────────────┐
# │ author   ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_date ┆ view_count │
# │ ---      ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ ---         ┆ ---        │
# │ i64      ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ date        ┆ f64        │
# ╞══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪═════════════╪════════════╡
# │ 16       ┆ uAaxjufrDjM ┆ 1        ┆ 0     ┆ … ┆ 3309     ┆ 2690.0     ┆ 2018-12-10  ┆ 228886.0   │
# │ 16       ┆ 8Ig-FoKo15M ┆ 1        ┆ 4     ┆ … ┆ 135      ┆ 4658.0     ┆ 2017-12-03  ┆ 224938.0   │
# │ 16       ┆ YIRZtGvq694 ┆ 1        ┆ 0     ┆ … ┆ 702      ┆ 25165.0    ┆ 2018-08-13  ┆ 563268.0   │
# │ 16       ┆ HJyfpL-O1WU ┆ 1        ┆ 0     ┆ … ┆ 216      ┆ 106212.0   ┆ 2018-05-19  ┆ 5.649267e6 │
# │ 16       ┆ NMCk4cVBr4I ┆ 1        ┆ 0     ┆ … ┆ 221      ┆ 382158.0   ┆ 2017-10-06  ┆ 2.9257455e │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆             ┆ 7          │
# │ …        ┆ …           ┆ …        ┆ …     ┆ … ┆ …        ┆ …          ┆ …           ┆ …          │
# │ 33481868 ┆ lN-rVlMIJZs ┆ 1        ┆ 0     ┆ … ┆ 421      ┆ 225249.0   ┆ 2016-04-21  ┆ 1.1922035e │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆             ┆ 7          │
# │ 33481868 ┆ vlo0-GDi-qc ┆ 2        ┆ 1     ┆ … ┆ 337      ┆ 104142.0   ┆ 2016-04-01  ┆ 5.782411e6 │
# │ 33481868 ┆ g_FB4Bw99KU ┆ 3        ┆ 5     ┆ … ┆ 313      ┆ 153964.0   ┆ 2016-03-13  ┆ 8.625662e6 │
# │ 33481868 ┆ IR0-o1bqaig ┆ 1        ┆ 0     ┆ … ┆ 376      ┆ 102792.0   ┆ 2015-07-31  ┆ 8.023453e6 │
# │ 33481868 ┆ uNLnBYqOXUA ┆ 1        ┆ 5     ┆ … ┆ 239      ┆ 80692.0    ┆ 2015-07-09  ┆ 5.736487e6 │
# └──────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴─────────────┴────────────┘

# %% [markdown]
# ### Create Dataset for Suspicious Users (Type-1)

# %%
# %%time
# Filter original youtube dataset to only contain suspicious users with comments per video > threshold

import os
import time

i = 0
chunksize = 100_000_000
processed_rows= 0
start_time = time.time()  # Record the start time
file_path = f"youtube_comments_filtered.parquet"

threshold = 8.67 # threshold = mean + 2*(std) = 1.32 + 2*(3.67) = 8.67

file_exists = os.path.exists(file_path) 
print(f"'{file_path}' exists? {file_exists}")

'''
NOTE: total_rows in youtube_comments.tsv.gz = 8_610_000_000
'''

for df in  pd.read_csv("./data/youtube_comments.tsv.gz", compression="infer", sep="\t", chunksize=chunksize): # chunksize = # of rows
    print("\nprocessing df chunk...")
    try:
        q = (
            pl.from_pandas(df)
            .lazy()  # Convert to lazy frame
            .group_by(['author', 'video_id'])
            .agg(
                comments=pl.col('video_id').count(),  # Count of video_id for each group
                likes=pl.col('likes').sum(),         # Sum of likes for each group
                replies=pl.col('replies').sum()      # Sum of replies for each group
            )
        )
    except Exception as e:
        print(f"Error encountered: {e}")
        print("Attempting to coerce non-numeric values and retry...")
        
        # Convert specific columns to numeric, coercing errors to NaN
        df['replies'] = pd.to_numeric(df['replies'], errors='coerce', downcast="integer").dropna().astype('int64')
        df['likes'] = pd.to_numeric(df['likes'], errors='coerce', downcast="integer").dropna().astype('int64')

        # Retry loading into Polars
        q = (
            pl.from_pandas(df)
            .lazy()
            .group_by(['author', 'video_id'])
            .agg(
                comments=pl.col('video_id').count(),
                likes=pl.col('likes').sum(),
                replies=pl.col('replies').sum()
            )
        )
    
    df_polars = q.collect()
    
    # filter authors with comments per day > threshold
    df_polars = q.collect().filter(pl.col('comments') > threshold)

    df_polars = df_polars.with_columns([
        pl.col("replies").cast(pl.Int64)
    ])
    df_polars = df_polars.with_columns([
        pl.col("likes").cast(pl.Int64)
    ])

    # Write the first chunk or append the next chunks
    if not file_exists:
        # Write the first chunk with header
        df_polars.write_parquet(file_path, compression='zstd')
        print(f"'{file_path}' saved.")
        file_exists = True
    else:
        # For subsequent chunks, load the existing Feather file, & overwrite it with updated data (append don't work with feather)
        print(f"reading '{file_path}'...")
        df_existing = pl.read_parquet(file_path, low_memory=True)
        df_combined = pl.concat([df_existing, df_polars])
        df_combined.write_parquet(file_path, compression='zstd')
        print(f"saved '{file_path}'. ")

    
    # Track the number of processed rows
    processed_rows += chunksize

    # Display progress
    print(f"iteration:{i+1}, processed_rows: {processed_rows:_}")
    i += 1

    current_time = time.time()     # Record the end time
    elapsed_time = current_time - start_time
    elapsed_hours = int(elapsed_time // 3600)
    elapsed_minutes = int((elapsed_time % 3600) // 60)
    elapsed_seconds = int(elapsed_time % 60)
    print(f"Elapsed time: {elapsed_hours:02}:{elapsed_minutes:02}:{elapsed_seconds:02}\n")
# Out:
# 'youtube_comments_filtered.parquet' exists? False
#
# processing df chunk...
# 'youtube_comments_filtered.parquet' saved.
# iteration:1, processed_rows: 100_000_000
# Elapsed time: 00:01:28
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:2, processed_rows: 200_000_000
# Elapsed time: 00:02:59
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:3, processed_rows: 300_000_000
# Elapsed time: 00:04:26
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:4, processed_rows: 400_000_000
# Elapsed time: 00:05:59
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:5, processed_rows: 500_000_000
# Elapsed time: 00:07:29
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:6, processed_rows: 600_000_000
# Elapsed time: 00:09:00
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:7, processed_rows: 700_000_000
# Elapsed time: 00:10:29
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:8, processed_rows: 800_000_000
# Elapsed time: 00:12:00
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:9, processed_rows: 900_000_000
# Elapsed time: 00:13:31
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:10, processed_rows: 1_000_000_000
# Elapsed time: 00:15:03
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:11, processed_rows: 1_100_000_000
# Elapsed time: 00:16:33
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:12, processed_rows: 1_200_000_000
# Elapsed time: 00:18:04
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:13, processed_rows: 1_300_000_000
# Elapsed time: 00:19:39
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:14, processed_rows: 1_400_000_000
# Elapsed time: 00:21:14
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:15, processed_rows: 1_500_000_000
# Elapsed time: 00:22:48
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:16, processed_rows: 1_600_000_000
# Elapsed time: 00:24:29
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:17, processed_rows: 1_700_000_000
# Elapsed time: 00:26:09
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:18, processed_rows: 1_800_000_000
# Elapsed time: 00:27:44
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:19, processed_rows: 1_900_000_000
# Elapsed time: 00:29:19
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:20, processed_rows: 2_000_000_000
# Elapsed time: 00:30:56
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:21, processed_rows: 2_100_000_000
# Elapsed time: 00:32:35
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:22, processed_rows: 2_200_000_000
# Elapsed time: 00:34:14
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:23, processed_rows: 2_300_000_000
# Elapsed time: 00:35:50
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:24, processed_rows: 2_400_000_000
# Elapsed time: 00:37:28
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:25, processed_rows: 2_500_000_000
# Elapsed time: 00:39:09
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:26, processed_rows: 2_600_000_000
# Elapsed time: 00:40:51
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:27, processed_rows: 2_700_000_000
# Elapsed time: 00:42:27
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:28, processed_rows: 2_800_000_000
# Elapsed time: 00:44:04
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:29, processed_rows: 2_900_000_000
# Elapsed time: 00:45:46
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:30, processed_rows: 3_000_000_000
# Elapsed time: 00:47:27
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:31, processed_rows: 3_100_000_000
# Elapsed time: 00:49:10
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:32, processed_rows: 3_200_000_000
# Elapsed time: 00:50:47
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:33, processed_rows: 3_300_000_000
# Elapsed time: 00:52:26
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:34, processed_rows: 3_400_000_000
# Elapsed time: 00:54:00
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:35, processed_rows: 3_500_000_000
# Elapsed time: 00:55:32
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:36, processed_rows: 3_600_000_000
# Elapsed time: 00:57:08
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:37, processed_rows: 3_700_000_000
# Elapsed time: 00:58:37
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:38, processed_rows: 3_800_000_000
# Elapsed time: 01:00:14
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:39, processed_rows: 3_900_000_000
# Elapsed time: 01:01:52
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:40, processed_rows: 4_000_000_000
# Elapsed time: 01:03:28
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:41, processed_rows: 4_100_000_000
# Elapsed time: 01:05:02
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:42, processed_rows: 4_200_000_000
# Elapsed time: 01:06:42
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:43, processed_rows: 4_300_000_000
# Elapsed time: 01:08:16
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:44, processed_rows: 4_400_000_000
# Elapsed time: 01:09:51
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:45, processed_rows: 4_500_000_000
# Elapsed time: 01:11:29
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:46, processed_rows: 4_600_000_000
# Elapsed time: 01:13:01
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:47, processed_rows: 4_700_000_000
# Elapsed time: 01:14:35
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:48, processed_rows: 4_800_000_000
# Elapsed time: 01:16:21
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:49, processed_rows: 4_900_000_000
# Elapsed time: 01:18:05
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:50, processed_rows: 5_000_000_000
# Elapsed time: 01:19:51
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:51, processed_rows: 5_100_000_000
# Elapsed time: 01:21:35
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:52, processed_rows: 5_200_000_000
# Elapsed time: 01:23:15
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:53, processed_rows: 5_300_000_000
# Elapsed time: 01:24:59
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:54, processed_rows: 5_400_000_000
# Elapsed time: 01:26:36
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:55, processed_rows: 5_500_000_000
# Elapsed time: 01:28:18
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:56, processed_rows: 5_600_000_000
# Elapsed time: 01:29:59
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:57, processed_rows: 5_700_000_000
# Elapsed time: 01:31:40
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:58, processed_rows: 5_800_000_000
# Elapsed time: 01:33:23
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:59, processed_rows: 5_900_000_000
# Elapsed time: 01:35:05
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:60, processed_rows: 6_000_000_000
# Elapsed time: 01:36:53
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:61, processed_rows: 6_100_000_000
# Elapsed time: 01:38:43
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:62, processed_rows: 6_200_000_000
# Elapsed time: 01:40:27
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:63, processed_rows: 6_300_000_000
# Elapsed time: 01:42:11
# <timed exec>:21: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
# processing df chunk...
# Error encountered: Could not convert '2' with type str: tried to convert to int64
# Attempting to coerce non-numeric values and retry...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:64, processed_rows: 6_400_000_000
# Elapsed time: 01:44:39
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:65, processed_rows: 6_500_000_000
# Elapsed time: 01:46:36
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:66, processed_rows: 6_600_000_000
# Elapsed time: 01:48:21
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:67, processed_rows: 6_700_000_000
# Elapsed time: 01:50:11
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:68, processed_rows: 6_800_000_000
# Elapsed time: 01:51:54
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:69, processed_rows: 6_900_000_000
# Elapsed time: 01:53:43
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:70, processed_rows: 7_000_000_000
# Elapsed time: 01:55:20
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:71, processed_rows: 7_100_000_000
# Elapsed time: 01:57:15
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:72, processed_rows: 7_200_000_000
# Elapsed time: 01:59:08
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:73, processed_rows: 7_300_000_000
# Elapsed time: 02:00:54
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:74, processed_rows: 7_400_000_000
# Elapsed time: 02:02:49
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:75, processed_rows: 7_500_000_000
# Elapsed time: 02:04:43
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:76, processed_rows: 7_600_000_000
# Elapsed time: 02:06:35
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:77, processed_rows: 7_700_000_000
# Elapsed time: 02:08:24
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:78, processed_rows: 7_800_000_000
# Elapsed time: 02:10:14
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:79, processed_rows: 7_900_000_000
# Elapsed time: 02:12:08
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:80, processed_rows: 8_000_000_000
# Elapsed time: 02:13:55
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:81, processed_rows: 8_100_000_000
# Elapsed time: 02:15:53
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:82, processed_rows: 8_200_000_000
# Elapsed time: 02:17:46
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:83, processed_rows: 8_300_000_000
# Elapsed time: 02:19:29
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:84, processed_rows: 8_400_000_000
# Elapsed time: 02:21:20
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:85, processed_rows: 8_500_000_000
# Elapsed time: 02:23:10
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:86, processed_rows: 8_600_000_000
# Elapsed time: 02:25:09
#
#
# processing df chunk...
# reading 'youtube_comments_filtered.parquet'...
# saved 'youtube_comments_filtered.parquet'.
# iteration:87, processed_rows: 8_700_000_000
# Elapsed time: 02:25:29
#
# CPU times: user 8h 10min 50s, sys: 1h 57min 50s, total: 10h 8min 41s
# Wall time: 2h 25min 29s

# %%
# Load dataset we just created of suspicious users with comments per day > threshold
suspicious_users = pl.read_parquet("youtube_comments_filtered.parquet")
suspicious_users
# Out:
# shape: (18_891_930, 5)
# ┌───────────┬─────────────┬──────────┬───────┬─────────┐
# │ author    ┆ video_id    ┆ comments ┆ likes ┆ replies │
# │ ---       ┆ ---         ┆ ---      ┆ ---   ┆ ---     │
# │ i64       ┆ str         ┆ u32      ┆ i64   ┆ i64     │
# ╞═══════════╪═════════════╪══════════╪═══════╪═════════╡
# │ 4183535   ┆ C_Zmr79SX7A ┆ 23       ┆ 62    ┆ 0       │
# │ 3580280   ┆ c9ho_gvXjjQ ┆ 9        ┆ 0     ┆ 0       │
# │ 6426424   ┆ Nbr1aZ3XTxk ┆ 53       ┆ 8     ┆ 0       │
# │ 2327535   ┆ OgBai7nR5E4 ┆ 11       ┆ 6     ┆ 0       │
# │ 5112800   ┆ NnhTuKa5FCw ┆ 14       ┆ 211   ┆ 0       │
# │ …         ┆ …           ┆ …        ┆ …     ┆ …       │
# │ 576541562 ┆ INIVR-VC-as ┆ 9        ┆ 11    ┆ 1       │
# │ 576512090 ┆ OxOqXxl-pbs ┆ 11       ┆ 7     ┆ 0       │
# │ 576327494 ┆ 3SjuC0PYscU ┆ 9        ┆ 53    ┆ 0       │
# │ 576204953 ┆ upL8g8RNRQY ┆ 11       ┆ 0     ┆ 6       │
# │ 576550081 ┆ A_USXO-cptk ┆ 15       ┆ 1308  ┆ 149     │
# └───────────┴─────────────┴──────────┴───────┴─────────┘

# %%
# Join videos metadata with suspicious users dataset & save it to disk
suspicious_users_chanel = suspicious_users.join(df_metadata_polars, on="video_id", how="inner")
suspicious_users_chanel.write_parquet("suspicious_users.parquet", compression='zstd')
suspicious_users_chanel.head()
# Out:
# shape: (5, 12)
# ┌───────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬────────────┬────────────┐
# │ author    ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_dat ┆ view_count │
# │ ---       ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ e          ┆ ---        │
# │ i64       ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ ---        ┆ f64        │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ datetime[n ┆            │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ s]         ┆            │
# ╞═══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪════════════╪════════════╡
# │ 59652612  ┆ ikPgqOPXiAw ┆ 11       ┆ 0     ┆ … ┆ 614      ┆ 8759.0     ┆ 2015-11-24 ┆ 6.044073e6 │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 67508742  ┆ mp9gt45aHxY ┆ 10       ┆ 2     ┆ … ┆ 1762     ┆ 29891.0    ┆ 2017-12-08 ┆ 2.3152662e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆ 7          │
# │ 297593699 ┆ yYRyznkNnL8 ┆ 11       ┆ 0     ┆ … ┆ 1525     ┆ 6722.0     ┆ 2017-06-13 ┆ 4.31813e6  │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 45096664  ┆ 3vQK78eUg2A ┆ 11       ┆ 0     ┆ … ┆ 2196     ┆ 8780.0     ┆ 2017-02-13 ┆ 6.67476e6  │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 246052255 ┆ 3vQK78eUg2A ┆ 9        ┆ 60    ┆ … ┆ 2196     ┆ 8780.0     ┆ 2017-02-13 ┆ 6.67476e6  │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# └───────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴────────────┴────────────┘

# %%
# Sanity checks
min_value = suspicious_users_chanel["comments"].min()
print(f"Sanity check to see the lowest number of comments made : {min_value}.")
print(f"So it should be higher than the threshold : {min_value > threshold}")
# Out:
# Sanity check to see the lowest number of comments made : 9.
# So it should be higher than the threshold : True

# %%
suspicious_users_chanel.sort("comments", descending = True).head(10)
# Out:
# shape: (10, 12)
# ┌───────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬────────────┬────────────┐
# │ author    ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_dat ┆ view_count │
# │ ---       ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ e          ┆ ---        │
# │ i64       ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ ---        ┆ f64        │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ datetime[n ┆            │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ s]         ┆            │
# ╞═══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪════════════╪════════════╡
# │ 260739815 ┆ qUWubraZ3Dg ┆ 30990    ┆ 0     ┆ … ┆ 208      ┆ 1754.0     ┆ 2007-02-14 ┆ 453386.0   │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 327375141 ┆ gHbYJfwFgOU ┆ 27973    ┆ 51923 ┆ … ┆ 152      ┆ 137619.0   ┆ 2012-08-23 ┆ 7.867065e6 │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 459327790 ┆ pRpeEdMmmQ0 ┆ 25107    ┆ 1393  ┆ … ┆ 211      ┆ 9.570906e6 ┆ 2010-06-04 ┆ 2.3633e9   │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 190348425 ┆ y6fThXQPT6I ┆ 24246    ┆ 1833  ┆ … ┆ 295      ┆ 953772.0   ┆ 2019-01-04 ┆ 7.3180617e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆ 7          │
# │ 503224102 ┆ Hb-TWv0Qe24 ┆ 24229    ┆ 7886  ┆ … ┆ 845      ┆ 136696.0   ┆ 2017-04-20 ┆ 1.0221193e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆ 7          │
# │ 219760968 ┆ 1J76wN0TPI4 ┆ 23475    ┆ 9055  ┆ … ┆ 184      ┆ 931061.0   ┆ 2018-05-30 ┆ 7.1293503e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆ 7          │
# │ 503224102 ┆ 4_FRxFioFzc ┆ 22077    ┆ 9506  ┆ … ┆ 590      ┆ 41044.0    ┆ 2015-11-05 ┆ 5.492312e6 │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 393529827 ┆ p_c6uQHlhZ0 ┆ 21081    ┆ 24055 ┆ … ┆ 318      ┆ 395298.0   ┆ 2017-11-04 ┆ 2.3712496e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆ 7          │
# │ 184412459 ┆ TjxZ6MrBl9E ┆ 20052    ┆ 1361  ┆ … ┆ 154      ┆ 30329.0    ┆ 2009-10-30 ┆ 2.794953e6 │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# │ 30292780  ┆ gHbYJfwFgOU ┆ 19678    ┆ 44143 ┆ … ┆ 152      ┆ 137619.0   ┆ 2012-08-23 ┆ 7.867065e6 │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00   ┆            │
# └───────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴────────────┴────────────┘

# %%
# Load dataset we just created of suspicious users with comments per day > threshold
suspicious_users = pl.read_parquet("suspicious_users.parquet")
suspicious_users
# Out:
# shape: (18_891_930, 12)
# ┌───────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬────────────┬────────────┐
# │ author    ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_dat ┆ view_count │
# │ ---       ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ e          ┆ ---        │
# │ i64       ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ ---        ┆ f64        │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆ date       ┆            │
# ╞═══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪════════════╪════════════╡
# │ 59652612  ┆ ikPgqOPXiAw ┆ 11       ┆ 0     ┆ … ┆ 614      ┆ 8759.0     ┆ 2015-11-24 ┆ 6.044073e6 │
# │ 67508742  ┆ mp9gt45aHxY ┆ 10       ┆ 2     ┆ … ┆ 1762     ┆ 29891.0    ┆ 2017-12-08 ┆ 2.3152662e │
# │           ┆             ┆          ┆       ┆   ┆          ┆            ┆            ┆ 7          │
# │ 297593699 ┆ yYRyznkNnL8 ┆ 11       ┆ 0     ┆ … ┆ 1525     ┆ 6722.0     ┆ 2017-06-13 ┆ 4.31813e6  │
# │ 45096664  ┆ 3vQK78eUg2A ┆ 11       ┆ 0     ┆ … ┆ 2196     ┆ 8780.0     ┆ 2017-02-13 ┆ 6.67476e6  │
# │ 246052255 ┆ 3vQK78eUg2A ┆ 9        ┆ 60    ┆ … ┆ 2196     ┆ 8780.0     ┆ 2017-02-13 ┆ 6.67476e6  │
# │ …         ┆ …           ┆ …        ┆ …     ┆ … ┆ …        ┆ …          ┆ …          ┆ …          │
# │ 430474027 ┆ BQGhbm7ygkY ┆ 12       ┆ 88    ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06 ┆ 6.885147e6 │
# │ 437403189 ┆ BQGhbm7ygkY ┆ 10       ┆ 82    ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06 ┆ 6.885147e6 │
# │ 446311653 ┆ BQGhbm7ygkY ┆ 11       ┆ 522   ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06 ┆ 6.885147e6 │
# │ 495878616 ┆ BQGhbm7ygkY ┆ 12       ┆ 70    ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06 ┆ 6.885147e6 │
# │ 532119980 ┆ BQGhbm7ygkY ┆ 10       ┆ 17    ┆ … ┆ 1213     ┆ 234072.0   ┆ 2019-08-06 ┆ 6.885147e6 │
# └───────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴────────────┴────────────┘

# %%
print("Suspicious Users - Comments Per Video:")
suspicious_users['comments'].describe()
# Out:
# Suspicious Users - Comments Per Video:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 1.889193e7 │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 21.605663  │
# │ std        ┆ 52.316513  │
# │ min        ┆ 9.0        │
# │ 25%        ┆ 10.0       │
# │ 50%        ┆ 13.0       │
# │ 75%        ┆ 20.0       │
# │ max        ┆ 30990.0    │
# └────────────┴────────────┘

# %% [markdown]
# ### Break Down Large Parquet Dataset into Small Partial Files

# %%
# Break down large Parquet file into smaller sub-files for uploading on Github
import polars as pl

dataset = 'normal_users'
rows_per_chunk = len(df) // 26 # for 'normal_users'

#dataset = 'suspicious_users'
#rows_per_chunk = len(df) // 5 # for 'suspicious_users'

df = pl.read_parquet(f"{dataset}.parquet")
n = 1
print(f"breaking down '{dataset}.parquet'...")

# Split and save each chunk based on rows
for i in range(0, len(df), rows_per_chunk):
    chunk_df = df.slice(i, rows_per_chunk)
    chunk_df.write_parquet(f'./data_type1/{dataset}_{n}.parquet')
    n += 1

print("done")
# Out:
# breaking down 'normal_users.parquet'...
# done

# %% [markdown]
# ### Read Partial Files to Create a DF

# %%
# To read partial Parquet files & create a single df
import polars as pl
import glob

dataset = 'normal_users'
#dataset = 'suspicious_users'

print(f"reading partial files '{dataset}_i.parquet'...")

# List all Parquet files
parquet_files = glob.glob(f'./data_type1/{dataset}_*.parquet')

# Read and concatenate all Parquet files
combined = pl.concat([pl.read_parquet(file) for file in parquet_files])
combined
# Out:
# reading partial files 'normal_users_i.parquet'...
# shape: (224_746_315, 12)
# ┌──────────┬─────────────┬──────────┬───────┬───┬──────────┬────────────┬─────────────┬────────────┐
# │ author   ┆ video_id    ┆ comments ┆ likes ┆ … ┆ duration ┆ like_count ┆ upload_date ┆ view_count │
# │ ---      ┆ ---         ┆ ---      ┆ ---   ┆   ┆ ---      ┆ ---        ┆ ---         ┆ ---        │
# │ i64      ┆ str         ┆ u32      ┆ i64   ┆   ┆ i64      ┆ f64        ┆ datetime[ns ┆ f64        │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ ]           ┆            │
# ╞══════════╪═════════════╪══════════╪═══════╪═══╪══════════╪════════════╪═════════════╪════════════╡
# │ 9587630  ┆ gza2-iPzPi4 ┆ 1        ┆ 0     ┆ … ┆ 977      ┆ 19517.0    ┆ 2018-05-27  ┆ 340224.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 9808653  ┆ gza2-iPzPi4 ┆ 1        ┆ 0     ┆ … ┆ 977      ┆ 19517.0    ┆ 2018-05-27  ┆ 340224.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 9842650  ┆ gza2-iPzPi4 ┆ 1        ┆ 0     ┆ … ┆ 977      ┆ 19517.0    ┆ 2018-05-27  ┆ 340224.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 10045235 ┆ gza2-iPzPi4 ┆ 1        ┆ 0     ┆ … ┆ 977      ┆ 19517.0    ┆ 2018-05-27  ┆ 340224.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 10156676 ┆ gza2-iPzPi4 ┆ 1        ┆ 0     ┆ … ┆ 977      ┆ 19517.0    ┆ 2018-05-27  ┆ 340224.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ …        ┆ …           ┆ …        ┆ …     ┆ … ┆ …        ┆ …          ┆ …           ┆ …          │
# │ 2598751  ┆ lcHBHxhp6p4 ┆ 1        ┆ 3     ┆ … ┆ 1737     ┆ 789.0      ┆ 2019-06-01  ┆ 76285.0    │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 1689039  ┆ FWGCmt5a8O4 ┆ 1        ┆ 0     ┆ … ┆ 346      ┆ 3411.0     ┆ 2019-06-01  ┆ 305577.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 582076   ┆ QXsW3R0EVaA ┆ 1        ┆ 0     ┆ … ┆ 5480     ┆ 3883.0     ┆ 2019-06-01  ┆ 385782.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 1689039  ┆ QXsW3R0EVaA ┆ 2        ┆ 5     ┆ … ┆ 5480     ┆ 3883.0     ┆ 2019-06-01  ┆ 385782.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# │ 3272337  ┆ QXsW3R0EVaA ┆ 3        ┆ 1     ┆ … ┆ 5480     ┆ 3883.0     ┆ 2019-06-01  ┆ 385782.0   │
# │          ┆             ┆          ┆       ┆   ┆          ┆            ┆ 00:00:00    ┆            │
# └──────────┴─────────────┴──────────┴───────┴───┴──────────┴────────────┴─────────────┴────────────┘

# %%
# Sanity Check
original = pl.read_parquet(f'{dataset}.parquet')
print("Original: ", original.describe())
print("Combined: ", combined.describe())
# Out:
# Original:  shape: (9, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ author    ┆ video_id  ┆ comments  ┆ … ┆ duration  ┆ like_coun ┆ upload_da ┆ view_cou │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ t         ┆ te        ┆ nt       │
# │ str       ┆ f64       ┆ str       ┆ f64       ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆ str       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 2.2474631 ┆ 224746315 ┆ 2.2474631 ┆ … ┆ 2.2474631 ┆ 2.2379684 ┆ 224746315 ┆ 2.247457 │
# │           ┆ 5e8       ┆           ┆ 5e8       ┆   ┆ 5e8       ┆ e8        ┆           ┆ 62e8     │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0.0       ┆ … ┆ 0.0       ┆ 949475.0  ┆ 0         ┆ 553.0    │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.6711e7  ┆ null      ┆ 1.187195  ┆ … ┆ 768.33530 ┆ 101019.83 ┆ 2016-12-0 ┆ 9.1728e6 │
# │           ┆           ┆           ┆           ┆   ┆ 7         ┆ 4245      ┆ 5 03:52:1 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5.199142  ┆          │
# │ std       ┆ 9.6698e6  ┆ null      ┆ 0.517646  ┆ … ┆ 1489.5770 ┆ 494325.55 ┆ null      ┆ 7.9840e7 │
# │           ┆           ┆           ┆           ┆   ┆ 74        ┆ 0403      ┆           ┆          │
# │ min       ┆ 16.0      ┆ ----meyKR ┆ 1.0       ┆ … ┆ 1.0       ┆ 0.0       ┆ 2005-05-2 ┆ 10.0     │
# │           ┆           ┆ 48        ┆           ┆   ┆           ┆           ┆ 4         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 25%       ┆ 8.327494e ┆ null      ┆ 1.0       ┆ … ┆ 265.0     ┆ 2580.0    ┆ 2015-11-1 ┆ 111938.0 │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 50%       ┆ 1.6713422 ┆ null      ┆ 1.0       ┆ … ┆ 548.0     ┆ 11874.0   ┆ 2017-07-1 ┆ 563527.0 │
# │           ┆ e7        ┆           ┆           ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 75%       ┆ 2.510346e ┆ null      ┆ 1.0       ┆ … ┆ 876.0     ┆ 52850.0   ┆ 2018-09-0 ┆ 2.70611e │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆ 7         ┆ 6        │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ max       ┆ 3.3481868 ┆ zzzwti5PN ┆ 4.0       ┆ … ┆ 360157.0  ┆ 3.5287325 ┆ 2019-10-3 ┆ 6.5099e9 │
# │           ┆ e7        ┆ _k        ┆           ┆   ┆           ┆ e7        ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# Combined:  shape: (9, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ author    ┆ video_id  ┆ comments  ┆ … ┆ duration  ┆ like_coun ┆ upload_da ┆ view_cou │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ t         ┆ te        ┆ nt       │
# │ str       ┆ f64       ┆ str       ┆ f64       ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆ str       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 2.2474631 ┆ 224746315 ┆ 2.2474631 ┆ … ┆ 2.2474631 ┆ 2.2379684 ┆ 224746315 ┆ 2.247457 │
# │           ┆ 5e8       ┆           ┆ 5e8       ┆   ┆ 5e8       ┆ e8        ┆           ┆ 62e8     │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0.0       ┆ … ┆ 0.0       ┆ 949475.0  ┆ 0         ┆ 553.0    │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.6711e7  ┆ null      ┆ 1.187195  ┆ … ┆ 768.33530 ┆ 101019.83 ┆ 2016-12-0 ┆ 9.1728e6 │
# │           ┆           ┆           ┆           ┆   ┆ 7         ┆ 4245      ┆ 5 03:52:1 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5.199142  ┆          │
# │ std       ┆ 9.6698e6  ┆ null      ┆ 0.517646  ┆ … ┆ 1489.5770 ┆ 494325.55 ┆ null      ┆ 7.9840e7 │
# │           ┆           ┆           ┆           ┆   ┆ 74        ┆ 0403      ┆           ┆          │
# │ min       ┆ 16.0      ┆ ----meyKR ┆ 1.0       ┆ … ┆ 1.0       ┆ 0.0       ┆ 2005-05-2 ┆ 10.0     │
# │           ┆           ┆ 48        ┆           ┆   ┆           ┆           ┆ 4         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 25%       ┆ 8.327494e ┆ null      ┆ 1.0       ┆ … ┆ 265.0     ┆ 2580.0    ┆ 2015-11-1 ┆ 111938.0 │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆ 9         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 50%       ┆ 1.6713422 ┆ null      ┆ 1.0       ┆ … ┆ 548.0     ┆ 11874.0   ┆ 2017-07-1 ┆ 563527.0 │
# │           ┆ e7        ┆           ┆           ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ 75%       ┆ 2.510346e ┆ null      ┆ 1.0       ┆ … ┆ 876.0     ┆ 52850.0   ┆ 2018-09-0 ┆ 2.70611e │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆ 7         ┆ 6        │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# │ max       ┆ 3.3481868 ┆ zzzwti5PN ┆ 4.0       ┆ … ┆ 360157.0  ┆ 3.5287325 ┆ 2019-10-3 ┆ 6.5099e9 │
# │           ┆ e7        ┆ _k        ┆           ┆   ┆           ┆ e7        ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 00:00:00  ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
